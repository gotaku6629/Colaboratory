# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/slGan"
# Out:
# /content/drive/My Drive/Colab Notebooks/slGan

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/slGan'

# %%
# !ls
# Out:
# DCGAN.ipynb	     gan.ipynb	      main.ipynb  MNIST_data
# Discriminator.ipynb  Generator.ipynb  MNIST	  output

# %%
# !jupyter nbconvert --to python 'DCGAN'.ipynb
# Out:
# [NbConvertApp] Converting notebook DCGAN.ipynb to python
# [NbConvertApp] Writing 8211 bytes to DCGAN.py

# %%
#cf)https://qiita.com/ttyszk/items/833d3753248bbc8a211f
# %tensorflow_version 1.x
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
import time
from pathlib import Path
from PIL import Image
from tensorflow.contrib.learn.python.learn.datasets import mnist
import csv

import DCGAN as dcGan

# %%
dataset = mnist.read_data_sets('MNIST_data', one_hot=True)
img = np.array(dataset.train.images[753])
plt.imshow(img.reshape(28,28))

# %%
X_train = (dataset.train.images - 0.5 ) / 0.5
len(X_train)
# Out:
# 55000

# %%
model = dcGan.DCGAN()
model.train(
    X_train=X_train,
    batch_size=100,
    epoch_num=51,
    init=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-cddb3e319ffc> in <module>()
# ----> 1 model = dcGan.DCGAN()
#       2 model.train(
#       3     X_train=X_train,
#       4     batch_size=100,
#       5     epoch_num=51,
#
# /content/drive/My Drive/Colab Notebooks/slGan/DCGAN.py in __init__(self)
#      43 class DCGAN():
#      44     def __init__(self):
# ---> 45         self.G_is_train = tf.placeholder(tf.bool)
#      46         self.D_is_train = tf.placeholder(tf.bool)
#      47         self.input_X = tf.placeholder(tf.float32, shape=(None, 28 * 28))
#
# NameError: name 'Generator' is not defined
